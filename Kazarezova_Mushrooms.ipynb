# %%
#Импортируем библиотеки
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt

#Открываем датасет
mr=pd.read_csv('mushrooms.csv')
#Смотрим на первые несколько строк
mr.head()
#Значение колонок узнаём на сайте, откуда загружен датасет
'''Attribute Information:
class: edible=e, poisonous=p
cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
bruises: bruises=t,no=f
odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s
gill-attachment: attached=a,descending=d,free=f,notched=n
gill-spacing: close=c,crowded=w,distant=d
gill-size: broad=b,narrow=n
gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y
stalk-shape: enlarging=e,tapering=t
stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?
stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
veil-type: partial=p,universal=u
veil-color: brown=n,orange=o,white=w,yellow=y
ring-number: none=n,one=o,two=t
ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z
spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y
population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y
habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d'''

#Вопрос 3.
#Узнаем, какого цвета обычно съедобные грибы и какого цвета они почти не бывают
#Для этого построим таблицу, где строками будет съедобность, а столбцами - цвет шляпки
print('Таблица сопряженности:\
 Edibility: Ed - edible, Po - Posonous;\
 Cap-color: N - brown, B - buff, C - cinnamon, G - gray, R - green, P - pink, U - purple, E - red, W - white, Y - yellow.')
print('     N  B  C   G   R  P  U   E   W   Y')
EdN = len(mr[mr['class']=='e'][mr['cap-color']=='n'])
EdB = len(mr[mr['class']=='e'][mr['cap-color']=='b'])
EdC = len(mr[mr['class']=='e'][mr['cap-color']=='c'])
EdG = len(mr[mr['class']=='e'][mr['cap-color']=='g'])
EdR = len(mr[mr['class']=='e'][mr['cap-color']=='r'])
EdP = len(mr[mr['class']=='e'][mr['cap-color']=='p'])
EdU = len(mr[mr['class']=='e'][mr['cap-color']=='u'])
EdE = len(mr[mr['class']=='e'][mr['cap-color']=='e'])
EdW = len(mr[mr['class']=='e'][mr['cap-color']=='w'])
EdY = len(mr[mr['class']=='e'][mr['cap-color']=='y'])
PoN = len(mr[mr['class']=='p'][mr['cap-color']=='n'])
PoB = len(mr[mr['class']=='p'][mr['cap-color']=='b'])
PoC = len(mr[mr['class']=='p'][mr['cap-color']=='c'])
PoG = len(mr[mr['class']=='p'][mr['cap-color']=='g'])
PoR = len(mr[mr['class']=='p'][mr['cap-color']=='r'])
PoP = len(mr[mr['class']=='p'][mr['cap-color']=='p'])
PoU = len(mr[mr['class']=='p'][mr['cap-color']=='u'])
Poe = len(mr[mr['class']=='p'][mr['cap-color']=='e'])
PoW = len(mr[mr['class']=='p'][mr['cap-color']=='w'])
PoY = len(mr[mr['class']=='p'][mr['cap-color']=='y'])
print(f'Ed {EdN} {EdB} {EdC} {EdG} {EdR} {EdP} {EdU} {EdE} {EdW} {EdY}')
print(f'Po {PoN} {PoB} {PoC} {PoG} {PoR} {PoP} {PoU} {Poe} {PoW} {PoY}')
#Вывод: больше всего съедобных грибов в датасете имеют шляпку коричневого цвета, меньше всего - шляпку зеленого или фиолетового цвета.
#Аналогичные таблицы можно построить для цвета гимениальной пластинки, ножки, вуали и спор.


#Вопрос 1.
#Нужно построить модель, которая предсказывала бы значение в колонке 'class' по значениям в других колонках
X = mr.drop(['class'], axis=1)
y=mr['class']

#Переводим категориальные переменные из текстовых в числовые
mrd_list = []
for name in mr.columns:
    mrd_list.append(pd.get_dummies(mr[name], prefix = name))
mrd = pd.concat(mrd_list, axis = 1)
mrd.head()

#Разбиваем выборку на тренировочную и тестовую
from sklearn.model_selection import train_test_split
from sklearn import linear_model
Xtrain, Xtest, ytrain, ytest = train_test_split(mrd, y, test_size=0.1)

#Классификатор
clas = linear_model.RidgeClassifier(alpha=.5)
clas.fit(Xtrain, ytrain) #Модель тренируется
ypred = clas.predict(Xtest) #Модель предсказывает
accuracy_score(ytest, ypred) #Узнаём точность предсказания

#Вывод: точность предсказания равна 1.0


#Вопрос 2.
#Найдем наиболее распространенные признаки несъедобных грибов
mrd[y == 'p']
quality = {}
for name in mrd.columns:
    quality[name] = np.sum(mrd[name])
from collections import Counter
counter = Counter(quality)
top_qualities = counter.most_common(5)
top_qualities

#Вывод: наиболее распространенными признаками несъедобных грибов являются (записано в виде <признак_значение, количество несъедобных грибов с этим значением признака в датасете>):
'''veil-type_p, 8124
veil-color_w, 7924
gill-attachment_f, 7914
ring-number_o, 7488
gill-spacing_c, 6812'''
# Out:
# Таблица сопряженности: Edibility: Ed - edible, Po - Posonous; Cap-color: N - brown, B - buff, C - cinnamon, G - gray, R - green, P - pink, U - purple, E - red, W - white, Y - yellow.
#      N  B  C   G   R  P  U   E   W   Y
# Ed 1264 48 32 1032 16 56 16 624 720 400
# Po 1020 120 12 808 0 88 0 876 320 672
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:44: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:46: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:47: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:48: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:49: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:50: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:51: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:52: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:53: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:54: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:55: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:56: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:57: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:58: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:59: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:60: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:61: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:62: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# D:\anaconda3\lib\site-packages\ipykernel_launcher.py:63: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-296a49139322> in <module>
#      89 clas.fit(Xtrain, ytrain) #Модель тренируется
#      90 ypred = clas.predict(Xtest) #Модель предсказывает
# ---> 91 accuracy_score(ytest, ypred) #Узнаём точность предсказания
#      92
#      93 #Вывод: точность предсказания равна 1.0
#
# NameError: name 'accuracy_score' is not defined
